# %%
from bs4 import BeautifulSoup

content_html = ''
with open('page2.html', 'r', encoding='utf-8') as html:
    content_html = html.read()

soup = BeautifulSoup(content_html, 'lxml')

# %%
import requests

headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36' 
}
url = "https://www.reclameaqui.com.br/empresa/prefeitura-fortaleza/lista-reclamacoes/?pagina=2"
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'lxml')

# %%
# Encontre todos os links (tags 'a')
links = soup.find_all('a')

# Inicialize uma lista para armazenar os links com 'h4' como filho
links_with_h4 = []

# Itere sobre os links e verifique se eles têm um 'h4' como filho
for link in links:
    h4 = link.find('h4')
    if h4 and 'title' in h4.attrs:
        links_with_h4.append(link)

# Obtenha os atributos 'href' dos links
for link in links_with_h4:
    print("Link:", link['href'])
# Out:
# Link: /prefeitura-fortaleza/iluminacao-publica_Lf6xOhfMUyGffO7W/
# Link: /prefeitura-fortaleza/site-fora-do-ar-para-cadastro-do-ciptea_q1cmZLLc-FY5DSTw/
# Link: /prefeitura-fortaleza/programa-nossas-guerreiras_YqCCWbBsv7diEbO6/
# Link: /prefeitura-fortaleza/projeto-nossas-guerreiras_b-xjf8AQLIr6KW_v/
# Link: /prefeitura-fortaleza/cras-do-castelao_-nD-wkS6Xr3G2k2F/
# Link: /prefeitura-fortaleza/falta-de-luz-na-rua_4QOUNbaUBC5sNwo-/
# Link: /prefeitura-fortaleza/o-ait-informado-nao-esta-apto-para-apresentar-defesa_EjKgF_WMrtLQBz78/
# Link: /prefeitura-fortaleza/barulho-de-bar-e-a-agefiz-nao-fiscaliza_tMU1tdkorQpPp9TI/
# Link: /prefeitura-fortaleza/falta-de-agua-diaria-da-cagece_MP1MgYqgelo_klsx/
# Link: /prefeitura-fortaleza/multa-indevida_1K4F2HEPsc9rOABP/

# %%
import pandas as pd
import numpy as np

csv_file = 'dags/complaints.csv'

df = pd.read_csv(csv_file, sep=';')
df = df.fillna(0)
for i, row in df.iterrows():
    print(row['id'])
    if np.isnan(row['id'])e:
        print('is none')
# Out:
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# is none
# ...

# %%
df.at[0, 'evaluated'] = True
df
# Out:
#      id                                                uri  title  \
# 0   NaN  /prefeitura-fortaleza/rua-sem-energia-a-mais-d...    NaN
# 1   NaN  /prefeitura-fortaleza/iluminacao-publica_Lf6xO...    NaN
# 2   NaN  /prefeitura-fortaleza/site-fora-do-ar-para-cad...    NaN
# 3   NaN  /prefeitura-fortaleza/programa-nossas-guerreir...    NaN
# 4   NaN  /prefeitura-fortaleza/projeto-nossas-guerreira...    NaN
# ..   ..                                                ...    ...
# 485 NaN  /prefeitura-fortaleza/reclamacao_6K84U4FshYNe-...    NaN
# 486 NaN  /prefeitura-fortaleza/semaforo-sem-tempo-para-...    NaN
# 487 NaN  /prefeitura-fortaleza/rua-esburacada_h_KjGiQ3y...    NaN
# 488 NaN  /prefeitura-fortaleza/limpeza-via-publica_YCI3...    NaN
# 489 NaN  /prefeitura-fortaleza/acumulo-de-entulho-e-lix...    NaN
#
#      description  created_at  city  answered  evaluated
# 0            NaN         NaN   NaN     False       True
# 1            NaN         NaN   NaN     False       True
# ...
