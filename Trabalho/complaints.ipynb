# %%
import pandas as pd
import numpy as np

csv_file = 'dags/complaints.csv'

df = pd.read_csv(csv_file, sep=';')

# %%
#df = df.drop(columns='evaluated')
#df.to_csv(csv_file, sep=';', index=False)

# %%
df[df['answered']]
# Out:
#             id                                                uri  \
# 89   167000041  /prefeitura-fortaleza/poste-em-via-movimentada...
# 98   167000041  /prefeitura-fortaleza/poste-em-via-movimentada...
# 107  167000041  /prefeitura-fortaleza/poste-em-via-movimentada...
# 116  167000041  /prefeitura-fortaleza/poste-em-via-movimentada...
# 125  167000041  /prefeitura-fortaleza/poste-em-via-movimentada...
# 134  167000041  /prefeitura-fortaleza/poste-em-via-movimentada...
# 143  167000041  /prefeitura-fortaleza/poste-em-via-movimentada...
# 152  167000041  /prefeitura-fortaleza/poste-em-via-movimentada...
# 161  167000041  /prefeitura-fortaleza/poste-em-via-movimentada...
# 169  163995435  /prefeitura-fortaleza/buracos-e-mais-buracos-n...
# 170  167000041  /prefeitura-fortaleza/poste-em-via-movimentada...
# 178  163995435  /prefeitura-fortaleza/buracos-e-mais-buracos-n...
# 187  163995435  /prefeitura-fortaleza/buracos-e-mais-buracos-n...
# ...
